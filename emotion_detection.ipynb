# %% [markdown]
# <a href="https://colab.research.google.com/github/Rathastha/rg-repo/blob/main/emotion_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 465.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 6.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=73bf219608e39429af87cba66039d4e9296a4162f4a9c3e28dabf8ae8acc0250
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %% [markdown]
# IMPORTING PYTHON MODULES

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
# Out:
# 23-12-29 13:40:37 - Directory /root/.deepface created
# 23-12-29 13:40:37 - Directory /root/.deepface/weights created

# %%
from google.colab import drive
drive.mount('/content/drive')
img = cv2.imread('/content/drive/MyDrive/emotion.jpeg')
plt.imshow(img[:,:,::-1])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result = DeepFace.analyze(img,actions = ['emotion'])
# Out:
# 23-12-29 13:41:46 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 15.2MB/s]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.021115707932040095, 'disgust': 0.00013928653288530768, 'fear': 0.003302513505332172, 'happy': 93.3207631111145, 'sad': 1.8062015995383263, 'surprise': 0.001112681820814032, 'neutral': 4.847370088100433}, 'dominant_emotion': 'happy', 'region': {'x': 514, 'y': 140, 'w': 325, 'h': 325}, 'face_confidence': 11.05888316425262}]

# %%
from google.colab import drive
drive.mount('/content/drive')
img = cv2.imread('/content/drive/MyDrive/ryan-snaadt-_LZbDkRaedE-unsplash.jpg')
plt.imshow(img[:,:,::-1])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result = DeepFace.analyze(img,actions = ['emotion'])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.40060777742313014, 'disgust': 2.1591863096586477e-05, 'fear': 99.59813950050709, 'happy': 0.00012080002572179227, 'sad': 1.0036707352824717e-05, 'surprise': 0.001102221060350675, 'neutral': 1.3562843324154812e-08}, 'dominant_emotion': 'fear', 'region': {'x': 1739, 'y': 531, 'w': 862, 'h': 862}, 'face_confidence': 7.167857217544224}, {'emotion': {'angry': 19.566279649734497, 'disgust': 4.316089674830437, 'fear': 21.854586899280548, 'happy': 7.410288827003342e-07, 'sad': 28.916072845458984, 'surprise': 5.526811629533768, 'neutral': 19.820165634155273}, 'dominant_emotion': 'sad', 'region': {'x': 1926, 'y': 1776, 'w': 347, 'h': 347}, 'face_confidence': 2.9324540797970258}]
